# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('inViales_2022_2024.csv')
df
# Out:
#                      folio fecha_creacion hora_creacion dia_semana  \
# 0       C2C/20211229/00212     2021-12-29      23:21:20  Miércoles
# 1       C2C/20211231/00183     2021-12-31      23:48:03    Viernes
# 2       C2C/20220101/00012     2022-01-01      01:06:39     Sábado
# 3       C2C/20220101/00070     2022-01-01      09:51:53     Sábado
# 4       C2N/20211231/00128     2021-12-31      23:03:05    Viernes
# ...                    ...            ...           ...        ...
# 504256   C5/20240229/04009     2024-02-29      19:53:36     Jueves
# 504257   C5/20240229/04038     2024-02-29      20:01:42     Jueves
# 504258   C5/20240229/04286     2024-02-29      20:43:20     Jueves
# 504259   C5/20240229/04300     2024-02-29      20:46:18     Jueves
# 504260   C5/20240229/04349     2024-02-29      20:53:56     Jueves
#
#        fecha_cierre hora_cierre tipo_incidente_c4           incidente_c4  \
# 0        2022-01-01    00:24:06         Lesionado            Atropellado
# 1        2022-01-01    06:29:52         Lesionado            Atropellado
# 2        2022-01-01    06:00:12         Accidente  Choque con lesionados
# 3        2022-01-01    12:54:10         Accidente           Motociclista
# 4        2022-01-01    06:16:42         Accidente  Choque sin lesionados
# ...             ...         ...               ...                    ...
# 504256   2024-02-29    23:16:21         Accidente  Choque con lesionados
# 504257   2024-02-29    23:06:17         Accidente  Choque con lesionados
# 504258   2024-02-29    23:46:22         Accidente  Choque con lesionados
# 504259   2024-02-29    23:56:17         Accidente           Motociclista
# 504260   2024-02-29    23:58:48         Accidente  Choque sin lesionados
#
#        alcaldia_inicio codigo_cierre  clas_con_f_alarma      tipo_entrada  \
# 0                  NaN             I  URGENCIAS MEDICAS  BOTÓN DE AUXILIO
# 1           CUAUHTEMOC             A  URGENCIAS MEDICAS  BOTÓN DE AUXILIO
# 2           CUAUHTEMOC             A  URGENCIAS MEDICAS  BOTÓN DE AUXILIO
# 3           CUAUHTEMOC             A  URGENCIAS MEDICAS             RADIO
# 4            IZTACALCO             A         EMERGENCIA  BOTÓN DE AUXILIO
# ...                ...           ...                ...               ...
# 504256      IZTAPALAPA             A  URGENCIAS MEDICAS   LLAMADA DEL 911
# 504257      CUAUHTEMOC             A  URGENCIAS MEDICAS             RADIO
# 504258      IZTAPALAPA             D  URGENCIAS MEDICAS   LLAMADA DEL 911
# 504259      IZTAPALAPA             F  URGENCIAS MEDICAS   LLAMADA DEL 911
# 504260      IZTAPALAPA             A         EMERGENCIA   LLAMADA DEL 911
#
#        alcaldia_cierre alcaldia_catalogo     colonia_catalogo   longitud  \
# 0                  NaN        Cuauhtémoc           Roma Norte -99.163670
# 1           CUAUHTEMOC        Cuauhtémoc               Obrera -99.144270
# 2           CUAUHTEMOC        Cuauhtémoc             Doctores -99.148320
# 3           CUAUHTEMOC    Miguel Hidalgo             Tlaxpana -99.165781
# 4            IZTACALCO         Iztacalco   Agricola Pantitlan -99.060450
# ...                ...               ...                  ...        ...
# 504256      IZTAPALAPA        Iztapalapa            El Vergel -99.087270
# 504257      CUAUHTEMOC        Cuauhtémoc               Centro -99.125200
# 504258      IZTAPALAPA        Iztapalapa             Apatlaco -99.119881
# 504259      IZTAPALAPA        Iztapalapa  Guadalupe Del Moral -99.080981
# 504260      IZTAPALAPA        Iztapalapa         Juan Escutia -99.054112
#
#           latitud
# 0       19.421610
# 1       19.409910
# 2       19.415250
# 3       19.443649
# 4       19.414620
# ...           ...
# 504256  19.320600
# 504257  19.428723
# 504258  19.380011
# 504259  19.369412
# 504260  19.397305
#
# [504261 rows x 17 columns]

# %%
df.fecha_creacion.min()
# Out:
# '2021-12-29'

# %%
df.fecha_creacion.max()
# Out:
# '2024-02-29'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504261 entries, 0 to 504260
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   folio              504261 non-null  object
#  1   fecha_creacion     504261 non-null  object
#  2   hora_creacion      504261 non-null  object
#  3   dia_semana         504261 non-null  object
#  4   fecha_cierre       504261 non-null  object
#  5   hora_cierre        504261 non-null  object
#  6   tipo_incidente_c4  504261 non-null  object
#  7   incidente_c4       504261 non-null  object
#  8   alcaldia_inicio    504226 non-null  object
#  9   codigo_cierre      504261 non-null  object
#  10  clas_con_f_alarma  504261 non-null  object
#  11  tipo_entrada       504256 non-null  object
#  12  alcaldia_cierre    504226 non-null  object
#  13  alcaldia_catalogo  503707 non-null  object
#  14  colonia_catalogo   493085 non-null  object
#  15  longitud           504261 non-null  float64
#  16  latitud            504261 non-null  float64
# dtypes: float64(2), object(15)
# memory usage: 65.4+ MB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 492856 entries, 1 to 504260
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   folio              492856 non-null  object
#  1   fecha_creacion     492856 non-null  object
#  2   hora_creacion      492856 non-null  object
#  3   dia_semana         492856 non-null  object
#  4   fecha_cierre       492856 non-null  object
#  5   hora_cierre        492856 non-null  object
#  6   tipo_incidente_c4  492856 non-null  object
#  7   incidente_c4       492856 non-null  object
#  8   alcaldia_inicio    492856 non-null  object
#  9   codigo_cierre      492856 non-null  object
#  10  clas_con_f_alarma  492856 non-null  object
#  11  tipo_entrada       492856 non-null  object
#  12  alcaldia_cierre    492856 non-null  object
#  13  alcaldia_catalogo  492856 non-null  object
#  14  colonia_catalogo   492856 non-null  object
#  15  longitud           492856 non-null  float64
#  16  latitud            492856 non-null  float64
# dtypes: float64(2), object(15)
# memory usage: 67.7+ MB

# %% [markdown]
# # EDA por colonia

# %%
# Suponiendo que df es tu DataFrame
result = df.groupby('colonia_catalogo').folio.count().sort_values(ascending=False).head(10)
result_df = pd.DataFrame(result).reset_index()

plt.figure(figsize=(10, 6))
plt.bar(result_df['colonia_catalogo'], result_df['folio'])
plt.xlabel('Colonia Catálogo')
plt.ylabel('Cantidad de Folios')
plt.title('Top 10 Colonias por Cantidad de Folios')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # EDA por fecha y año

# %%
df['fecha_creacion'] = pd.to_datetime(df['fecha_creacion'])

result = df.groupby('fecha_creacion').folio.count().sort_index()
filtered_result = result.loc['2022-01-01':'2022-12-31']

result_df = pd.DataFrame(filtered_result).reset_index()

plt.figure(figsize=(12, 6))
plt.plot(result_df['fecha_creacion'], result_df['folio'], marker='o', linestyle='-')
plt.xlabel('Fecha de Creación')
plt.ylabel('Cantidad de Folios')
plt.title('Estacionalidad de Folios por Fecha en 2022')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %%
df['fecha_creacion'] = pd.to_datetime(df['fecha_creacion'])

result = df.groupby('fecha_creacion').folio.count().sort_index()
filtered_result = result.loc['2023-01-01':'2023-12-31']

result_df = pd.DataFrame(filtered_result).reset_index()

plt.figure(figsize=(12, 6))
plt.plot(result_df['fecha_creacion'], result_df['folio'], marker='o', linestyle='-')
plt.xlabel('Fecha de Creación')
plt.ylabel('Cantidad de Folios')
plt.title('Estacionalidad de Folios por Fecha en 2023')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %% [markdown]
# # EDA por hora

# %%
df['hora_creacion'] = pd.to_datetime(df['hora_creacion'], format='%H:%M:%S')

df['hora_redondeada'] = df['hora_creacion'].dt.round('H')

result = df.groupby('hora_redondeada').folio.count()

result_df = pd.DataFrame(result).reset_index()

result_df['hora_redondeada'] = result_df['hora_redondeada'].dt.strftime('%H:%M')

plt.figure(figsize=(12, 6))
plt.plot(result_df['hora_redondeada'], result_df['folio'], marker='o', linestyle='-')
plt.xlabel('Hora de Creación (Redondeada)')
plt.ylabel('Cantidad de Folios')
plt.title('Estacionalidad de Folios por Hora')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %% [markdown]
# ## PROPUESTA PROYECTO

# %%
df1 = pd.read_csv('infracciones_infracciones_transito_2023_b2.csv')
print(df1.columns)
print(df1.head())
# Out:
# /var/folders/dh/nbzj0wyx6rq090qyn7s_41nr0000gn/T/ipykernel_3347/3915475457.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('infracciones_infracciones_transito_2023_b2.csv')
# Index(['id_infraccion', 'fecha_infraccion', 'ao_infraccion', 'mes',
#        'categoria', 'articulo', 'fraccion', 'inciso', 'parrafo', 'placa',
#        'color', 'marca_general', 'marca', 'submarca', 'en_la_calle',
#        'entre_calle', 'y_calle', 'colonia', 'alcaldia', 'codigo_postal',
#        'longitud', 'latitud'],
#       dtype='object')
#    id_infraccion fecha_infraccion  ao_infraccion  mes categoria  articulo  \
# 0  id-4225409013       2023-03-24           2023  NaN      Otra         5
# 1  id-4225363155       2023-03-21           2023  NaN      Otra         6
# 2  id-4225548620       2023-04-03           2023  NaN      Otra         6
# 3  id-4225613632       2023-04-07           2023  NaN      Otra         6
# 4  id-4225694686       2023-04-13           2023  NaN      Otra         6
#
#   fraccion inciso  parrafo    placa  ...        marca               submarca  \
# 0       IX  -----    -----  002A399  ...  DESCONOCIDO        YARIS 5 PUERTAS
# 1       II  -----  PRIMERO  HG0572C  ...         FORD            DESCONOCIDO
# 2        I      C  PRIMERO   A4159M  ...    CHEVROLET                   AVEO
# 3        I      A  PRIMERO   A8271G  ...       NISSAN  TIIDA SEDÁN 4 PUERTAS
# 4        I      A  PRIMERO   64DFU9  ...  DESCONOCIDO            DESCONOCIDO
#
#                      en_la_calle       entre_calle              y_calle  \
# 0                    Eje Central            eje 1          eje central
# 1                     Metrobus 6  Ignacio Allende             EJE 5 nte
# 2  Calle Doctor Martínez del Río       José terres  Isabel la católica
# 3               baja California        cuauhtémoc           dr Jiménez
# 4                 Vidal Alcocer       peña y peña          Berriozábal
#
#               colonia           alcaldia codigo_postal longitud latitud
# 0              CENTRO         Cuauhtémoc           NaN      NaN     NaN
# 1  SAN JUAN DE ARAGÓN  Gustavo A. Madero           NaN      NaN     NaN
# 2            DOCTORES         Cuauhtémoc           NaN      NaN     NaN
# 3            DOCTORES         Cuauhtémoc           NaN      NaN     NaN
# 4              CENTRO         Cuauhtémoc           NaN      NaN     NaN
#
# [5 rows x 22 columns]

# %%
df1['longitud'].isna().count()
df1.shape
# Out:
# (538810, 22)

# %%
df1.alcaldia.unique()
# Out:
# array(['Cuauhtémoc', 'Gustavo A. Madero', 'Tláhuac', 'Iztacalco',
#        'Benito Juárez', 'Miguel Hidalgo', 'Iztapalapa', 'Azcapotzalco',
#        'Coyoacán', 'Venustiano Carranza', 'Cuajimalpa de Morelos',
#        'Álvaro Obregón', 'La Magdalena Contreras', 'Tlalpan',
#        'Xochimilco', 'Milpa Alta', 'Desconocido'], dtype=object)

# %%
df.alcaldia_catalogo.unique()
# Out:
# array(['Cuauhtémoc', 'Miguel Hidalgo', 'Iztacalco', 'Venustiano Carranza',
#        'Gustavo A. Madero', 'Xochimilco', 'Tláhuac', 'Iztapalapa',
#        'Álvaro Obregón', 'Azcapotzalco', 'Tlalpan', 'Coyoacán',
#        'Milpa Alta', 'Benito Juárez', 'Cuajimalpa de Morelos',
#        'La Magdalena Contreras'], dtype=object)

# %%
# Assuming df and df1 are your DataFrames
unique_values_df = set(df.alcaldia_catalogo.unique())
unique_values_df1 = set(df1.alcaldia.unique())

# Values in df.alcaldia_catalogo.unique() but not in df1.alcaldia.unique()
not_in_df1 = unique_values_df - unique_values_df1

# Values in df1.alcaldia.unique() but not in df.alcaldia_catalogo.unique()
not_in_df = unique_values_df1 - unique_values_df

print("Values in df.alcaldia_catalogo.unique() but not in df1.alcaldia.unique():")
print(not_in_df1)
print("\nValues in df1.alcaldia.unique() but not in df.alcaldia_catalogo.unique():")
print(not_in_df)
# Out:
# Values in df.alcaldia_catalogo.unique() but not in df1.alcaldia.unique():
# set()
#
# Values in df1.alcaldia.unique() but not in df.alcaldia_catalogo.unique():
# {'Desconocido'}

# %%
# Remove 'nan' from df.alcaldia_catalogo and 'Desconocido' from df1.alcaldia
deleted_from_df = df[df['alcaldia_catalogo'].notna()]['alcaldia_catalogo'].unique()
deleted_from_df1 = df1[df1['alcaldia'] != 'Desconocido']['alcaldia'].unique()

# Count how many were deleted
num_deleted_from_df = len(deleted_from_df)
num_deleted_from_df1 = len(deleted_from_df1)

# Update the DataFrames by removing the values
df = df[df['alcaldia_catalogo'].notna()]
df1 = df1[df1['alcaldia'] != 'Desconocido']

print("Number of values deleted from df.alcaldia_catalogo:", num_deleted_from_df)
print("Number of values deleted from df1.alcaldia:", num_deleted_from_df1)
# Out:
# Number of values deleted from df.alcaldia_catalogo: 16
# Number of values deleted from df1.alcaldia: 16

# %%
print(df1.categoria.unique()[3])
print(df1.categoria.unique()[-1])
# Out:
# Exceder límites de velocidad
# Conducir bajo los efectos del alcohol

# %%
# Count the number of values in each category for 'alcaldia_catalogo' in df and print
print("Count of values in each category for 'alcaldia_catalogo' in df:")
print(df['alcaldia_catalogo'].value_counts())
print("\n")

# Count how many times each 'alcaldia_catalogo' has either "Exceder límites de velocidad" or "Conducir bajo los efectos del alcohol" in the 'categoria' column of df1
print("Count of occurrences of 'Exceder límites de velocidad' and 'Conducir bajo los efectos del alcohol' for each 'alcaldia_catalogo' in df1:")
filtered_df1 = df1[df1['categoria'].isin(["Exceder límites de velocidad", "Conducir bajo los efectos del alcohol"])]
print(filtered_df1['alcaldia'].value_counts())
# Out:
# Count of values in each category for 'alcaldia_catalogo' in df:
# alcaldia_catalogo
# Iztapalapa                81660
# Gustavo A. Madero         56032
# Cuauhtémoc                52238
# Venustiano Carranza       37174
# Coyoacán                  36922
# Benito Juárez             36135
# Tlalpan                   33978
# Álvaro Obregón            33752
# Miguel Hidalgo            31512
# Iztacalco                 23843
# Azcapotzalco              20559
# Xochimilco                17455
# Tláhuac                   13612
# Cuajimalpa de Morelos      8062
# La Magdalena Contreras     7477
# Milpa Alta                 2445
# Name: count, dtype: int64
#
#
# Count of occurrences of 'Exceder límites de velocidad' and 'Conducir bajo los efectos del alcohol' for each 'alcaldia_catalogo' in df1:
# alcaldia
# Miguel Hidalgo            163169
# Álvaro Obregón             80456
# Iztapalapa                 36734
# Venustiano Carranza        24634
# Benito Juárez              22912
# Cuauhtémoc                 17730
# Gustavo A. Madero           8828
# La Magdalena Contreras      1779
# Iztacalco                   1100
# Azcapotzalco                 187
# Xochimilco                     5
# Coyoacán                       1
# Tlalpan                        1
# Name: count, dtype: int64

# %%
df.tipo_incidente_c4.unique()
# Out:
# array(['Lesionado', 'Accidente', 'Cadáver', 'Mi Taxi',
#        'Detención ciudadana', 'Mi Calle', 'Sismo'], dtype=object)

# %%
df1[df1["placa"]==""]
# Out:
# Empty DataFrame
# Columns: [id_infraccion, fecha_infraccion, ao_infraccion, mes, categoria, articulo, fraccion, inciso, parrafo, placa, color, marca_general, marca, submarca, en_la_calle, entre_calle, y_calle, colonia, alcaldia, codigo_postal, longitud, latitud]
# Index: []
#
# [0 rows x 22 columns]
